# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejashri-Jayachandran/kranti2k23/blob/main/DS_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/HousePriceIndia.csv')

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
sns.countplot(data=df,x='number of bedrooms')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
sns.countplot(data=df,x='number of bathrooms')sns.boxplot(df['living area'])
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='count'>

# %%
plt.scatter(df.index,df['number of bathrooms'])
plt.show()

# %%
sns.scatterplot(x=df.index,y=df['number of bedrooms'],hue=df['Price'])
# Out:
# <Axes: ylabel='number of bedrooms'>

# %%
sns.boxplot(df['living area'])
# Out:
# <Axes: >

# %%
sns.lineplot(data=df,x="living area",y="lot area")
# Out:
# <Axes: xlabel='living area', ylabel='lot area'>

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.stripplot(data=df,x='Built Year',y='Price',hue='waterfront present')
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %%
sns.violinplot(data=df,x='living area',y='lot area',hue='number of floors')
# Out:
# <Axes: xlabel='living area', ylabel='lot area'>

# %%
sns.pointplot(data=df,x='condition of the house',y='grade of the house',hue='waterfront present')
# Out:
# <Axes: xlabel='condition of the house', ylabel='grade of the house'>

# %%
df['number of bedrooms'].median()
# Out:
# 3.0

# %%
df['Area of the basement'].mode()
# Out:
# 0    0
# Name: Area of the basement, dtype: int64

# %%
df['Area of the basement'].mean()
# Out:
# 296.47906976744184

# %%
df['number of floors'].mode()
# Out:
# 0    1.0
# Name: number of floors, dtype: float64

# %%
sns.countplot(data=df,x='number of views',hue='Number of schools nearby')
# Out:
# <Axes: xlabel='number of views', ylabel='count'>
